# %%
from search import find
find('شكون رئيس تونس من 2019 اللي 2020 ',wiki_alone=True)
# Out:
# ['رئيس الجمهورية التونسية', 'درة (ممثلة)', 'أتاي', 'عاصي الرحباني', 'أحمد حسن البكر', 'نوال الزغبي', 'موريون', 'محمد القصبجي', 'لطفي العبدلي', 'لطيفة (مغنية)']
# ...
